# %%
import numpy as np
import imageio as io
from skimage.util import crop

for x in range(18):
    full_volume = io.volread('E:/paper_2/Volumes_Cat/TiffSaver-tomo_C%d.tif'%(x))
    vol = crop(full_volume, ((0, 1510),(870, 5), (270, 255)), copy=True)
    io.volsave('E:/paper_2/Registration_Volumes/cropped_TiffSaver-tomo_C%d.tif'%(x), vol, format = 'tiff')

# %%
img = io.volread('E:/paper_2/Registration_Volumes/cropped_TiffSaver-tomo_C0.tif')
img1 = io.volread('E:/paper_2/Registration_Volumes/cropped_TiffSaver-tomo_C3.tif')
img2 = io.volread('E:/paper_2/Registration_Volumes/cropped_TiffSaver-tomo_C6.tif')
img3 = io.volread('E:/paper_2/Registration_Volumes/cropped_TiffSaver-tomo_C15.tif')

# %%
import imageio as io
io.imsave('E:/paper_2/img0b.tif', img[150], format='tiff')
io.imsave('E:/paper_2/img0c.tif', img[275], format='tiff')
io.imsave('E:/paper_2/img1.tif', img1[475], format='tiff')
io.imsave('E:/paper_2/img2.tif', img2[475], format='tiff')
io.imsave('E:/paper_2/img3.tif', img3[475], format='tiff')
